# %%
import matplotlib.pyplot as plt
import os
import numpy as np

# %%
with open("/home/sumin/catkin_ws/src/track_map_generate/path/utm_x.txt","r") as f:
    utm_x = f.readlines()

for i in range(len(utm_x)):
    
    utm_x[i] = utm_x[i].replace("\n","")

# %%
with open("/home/sumin/catkin_ws/src/track_map_generate/path/utm_y.txt","r") as f:
    utm_y = f.readlines()

for i in range(len(utm_y)):
    
    utm_y[i] = utm_y[i].replace("\n","")

# %%
print(len(utm_x), len(utm_y))
# Out:
# 160 160

# %%
x=[]
y=[]
for i in range(len(utm_x)):
    x.append(float(utm_x[i]))
for i in range(len(utm_y)):
    y.append(float(utm_y[i])) 
plt.figure(figsize=(20,20))
plt.scatter(x,y)
plt.show()

# %%
import rospy
